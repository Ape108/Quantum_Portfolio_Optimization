# %% [markdown]
# <a href="https://colab.research.google.com/github/Ape108/Quantum_Portfolio_Optimization/blob/main/STTM_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Environment Setup

# %%
import pandas as pd
import os
from google.colab import drive
from datetime import datetime, timedelta
import yfinance as yf
import random
import time
from torch.utils.data import Dataset
import json
import torch
import torch.nn as nn
from torch.nn import MSELoss
from torch.optim import Adam
from tqdm import tqdm
import numpy as np
from torch.utils.data import DataLoader, random_split
import shutil
from torch.cuda.amp import autocast, GradScaler
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
drive.mount('/content/drive')

# %%
# Define base directory on Google Drive
base_dir = "/content/drive/MyDrive/StockProject/StockProjectDataPrep"
data_dir = os.path.join(base_dir, "data")
log_dir = os.path.join(base_dir, "logs")
ticker_path = os.path.join(base_dir, "tickers", "all_us_tickers.csv")
valid_tickers_path = os.path.join(base_dir, "valid_tickers.csv")
ticker_log_path = os.path.join(log_dir, "ticker_changes.txt")

os.makedirs(data_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(os.path.join(base_dir, "tickers"), exist_ok=True)

# === CONFIG ===
history_window = 30
prediction_window = 7
min_required_days = history_window + prediction_window
start_date = (datetime.now() - timedelta(days=365)).strftime('%Y-%m-%d')

# %% [markdown]
# #Load Tickers

# %%
# === 1. LOAD RAW TICKERS ===
def load_all_us_tickers():
    try:
        nasdaq_url = "ftp://ftp.nasdaqtrader.com/SymbolDirectory/nasdaqlisted.txt"
        other_url = "ftp://ftp.nasdaqtrader.com/SymbolDirectory/otherlisted.txt"

        nasdaq = pd.read_csv(nasdaq_url, sep="|")
        nasdaq = nasdaq[nasdaq['Test Issue'] == 'N']
        nasdaq_tickers = nasdaq['Symbol'].dropna().astype(str).tolist()

        other = pd.read_csv(other_url, sep="|")
        other = other[other['Test Issue'] == 'N']
        nyse_tickers = other['ACT Symbol'].dropna().astype(str).tolist()

        all_tickers = sorted(list(set(nasdaq_tickers + nyse_tickers)))

        # Log changes
        if os.path.exists(ticker_path):
            old_df = pd.read_csv(ticker_path)
            old_tickers = set(old_df['Ticker'])
            new_tickers = set(all_tickers)

            added = sorted(new_tickers - old_tickers)
            removed = sorted(old_tickers - new_tickers)

            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            with open(ticker_log_path, "a") as log:
                log.write(f"\n[{timestamp}]\n")
                log.write(f"Added ({len(added)}): {', '.join(added)}\n")
                log.write(f"Removed ({len(removed)}): {', '.join(removed)}\n")

        pd.DataFrame({"Ticker": all_tickers}).to_csv(ticker_path, index=False)
        print(f"✅ Saved {len(all_tickers)} tickers to: {ticker_path}")
    except Exception as e:
        print(f"❌ Failed to load tickers: {e}")

# %% [markdown]
# #Historical Data

# %%
# === 2. DOWNLOAD TICKER HISTORICAL DATA WITH RETRY ===
def download_ticker_data(ticker, start=start_date, max_retries=3):
    for attempt in range(max_retries):
        try:
            df = yf.download(ticker, start=start, progress=False)
            if df.empty:
                raise ValueError("No data returned")
            df.reset_index().to_csv(os.path.join(data_dir, f"{ticker}.csv"), index=False)
            return True
        except Exception as e:
            if attempt == max_retries - 1:
                with open(os.path.join(log_dir, "failed_downloads.txt"), "a") as f:
                    f.write(f"{ticker}: {e}\n")
            time.sleep(1)
    return False

# %% [markdown]
# #Validate Data

# %%
# === 3. VALIDATE DATA ===
def is_valid_ticker(ticker):
    path = os.path.join(data_dir, f"{ticker}.csv")
    if not os.path.exists(path):
        return False
    try:
        df = pd.read_csv(path)
        df = df.sort_values("Date")
        df = df[["Open", "High", "Low", "Close", "Volume"]].apply(pd.to_numeric, errors="coerce")
        df = df.dropna()

        if len(df) < min_required_days:
            print(f"❌ {ticker} skipped (only {len(df)} valid rows)")
            return False

        df = df[-min_required_days:]
        df = df[["Open", "High", "Low", "Close", "Volume"]].apply(pd.to_numeric, errors='coerce')
        if df.isnull().values.any():
            return False
        return True
    except Exception as e:
        with open(os.path.join(log_dir, "corrupt_tickers.txt"), "a") as f:
            f.write(f"{ticker}: {e}\n")
        return False

# %% [markdown]
# #Parallel Download Wrapper

# %%
# === 4. PARALLEL DOWNLOAD WRAPPER ===
def download_all_tickers(tickers, max_workers=8):
    print(f"🔄 Downloading {len(tickers)} tickers in parallel with {max_workers} workers...")
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(download_ticker_data, t): t for t in tickers}
        for future in as_completed(futures):
            ticker = futures[future]
            try:
                future.result()
            except Exception as e:
                with open(os.path.join(log_dir, "failed_downloads.txt"), "a") as f:
                    f.write(f"{ticker} (thread error): {e}\n")

# %%
load_all_us_tickers()

# %%
tickers = pd.read_csv(ticker_path)['Ticker'].tolist()
download_all_tickers(tickers, max_workers=8)
# Out:
# ✅ Saved 11328 tickers to: /content/drive/MyDrive/StockProject/StockProjectDataPrep/tickers/all_us_tickers.csv
# 🔄 Downloading 11328 tickers in parallel with 8 workers...
# YF.download() has changed argument auto_adjust default to True
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACT.U']: HTTPError('HTTP Error 401: ')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ABLVW']: YFInvalidPeriodError("ABLVW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$E', 'ABR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ABR$E', 'ABR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$E', 'ABR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABR$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ADVWW']: YFInvalidPeriodError("ADVWW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AERTW']: YFInvalidPeriodError("AERTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AEVAW']: YFInvalidPeriodError("AEVAW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFJKR']: YFInvalidPeriodError("AFJKR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFRIW']: YFInvalidPeriodError("AFRIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFRIW']: YFInvalidPeriodError("AFRIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFRIW']: YFInvalidPeriodError("AFRIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AFRIW']: YFInvalidPeriodError("AFRIW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AIMDW']: YFInvalidPeriodError("AIMDW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIRJW']: YFInvalidPeriodError("AIRJW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AIRJW']: YFInvalidPeriodError("AIRJW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AKO.B', 'AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ALFUW']: YFInvalidPeriodError("ALFUW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALUR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALUR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALUR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ALUR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALUR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMBI.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AMBI.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMBI.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMODW']: YFInvalidPeriodError("AMODW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMODW']: YFInvalidPeriodError("AMODW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMODW']: YFInvalidPeriodError("AMODW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMODW']: YFInvalidPeriodError("AMODW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMPX.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ANG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANG$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ANG$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AP.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['APO$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARBEW']: YFInvalidPeriodError("ARBEW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AREBW']: YFInvalidPeriodError("AREBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARKOW']: YFInvalidPeriodError("ARKOW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ARR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ASPCR']: YFInvalidPeriodError("ASPCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ATCO$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATMCR']: YFInvalidPeriodError("ATMCR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['AUB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['AUROW']: YFInvalidPeriodError("AUROW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AVGG']: YFInvalidPeriodError("AVGG: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CLBR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BA$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BARK.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BC$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BC$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BC$C', 'BC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BC$C', 'BC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BC$C', 'BC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['BC$C', 'BC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BC$C', 'BC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BC$C', 'BC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCTXW']: YFInvalidPeriodError("BCTXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BCV$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BEAGR']: YFInvalidPeriodError("BEAGR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BEP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BETRW']: YFInvalidPeriodError("BETRW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['BFRGW']: YFInvalidPeriodError("BFRGW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BHR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIP$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BIP$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ...
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISTW']: YFInvalidPeriodError("DISTW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLNG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLNG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLNG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLNG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLNG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLNG$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLR$J']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLR$J']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['DLR$J']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLR$J']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DLR$J']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DMYY.U']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRDBW']: YFInvalidPeriodError("DRDBW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRTSW']: YFInvalidPeriodError("DRTSW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DSX$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DUK$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DX$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:['DYNXW']: YFInvalidPeriodError("DYNXW: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECC$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECC$D']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['ECF$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EFC$B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EONR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['EPR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQH$C']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EQV.W']: YFTzMissingError('possibly delisted; no timezone found')
# ✅ 0 valid tickers saved to: /content/drive/MyDrive/StockProject/StockProjectDataPrep/valid_tickers.csv

# %%
valid = [t for t in tickers if is_valid_ticker(t)]
pd.DataFrame({"Ticker": valid}).to_csv(valid_tickers_path, index=False)
print(f"✅ {len(valid)} valid tickers saved to: {valid_tickers_path}")
# Out:
# ❌ AAPG skipped (only 29 valid rows)
# ❌ AAPL skipped (only 29 valid rows)
# ❌ AAPR skipped (only 29 valid rows)
# ❌ AAPU skipped (only 29 valid rows)
# ❌ AAPW skipped (only 29 valid rows)
# ❌ AAPX skipped (only 29 valid rows)
# ❌ AAPY skipped (only 29 valid rows)
# ❌ AARD skipped (only 29 valid rows)
# ❌ ACVF skipped (only 27 valid rows)
# ❌ ACVT skipped (only 27 valid rows)
# ❌ ACWI skipped (only 27 valid rows)
# ❌ ACWV skipped (only 27 valid rows)
# ❌ ACWX skipped (only 27 valid rows)
# ❌ ACXP skipped (only 27 valid rows)
# ❌ ADAG skipped (only 27 valid rows)
# ❌ ADAP skipped (only 27 valid rows)
# ❌ ADVM skipped (only 18 valid rows)
# ❌ ADVWW skipped (only 18 valid rows)
# ❌ ADX skipped (only 18 valid rows)
# ❌ ADXN skipped (only 18 valid rows)
# ❌ AEE skipped (only 18 valid rows)
# ❌ AEF skipped (only 18 valid rows)
# ❌ AEFC skipped (only 18 valid rows)
# ❌ AEG skipped (only 18 valid rows)
# ❌ AEO skipped (only 18 valid rows)
# ❌ AEON skipped (only 18 valid rows)
# ❌ AEP skipped (only 18 valid rows)
# ❌ AER skipped (only 18 valid rows)
# ❌ AERT skipped (only 18 valid rows)
# ❌ AERTW skipped (only 18 valid rows)
# ❌ AES skipped (only 18 valid rows)
# ❌ AESI skipped (only 18 valid rows)
# ❌ ALC skipped (only 12 valid rows)
# ❌ ALCO skipped (only 12 valid rows)
# ❌ ALCY skipped (only 12 valid rows)
# ❌ AMID skipped (only 0 valid rows)
# ❌ AMN skipped (only 0 valid rows)
# ❌ AMPGW skipped (only 0 valid rows)
# ❌ APWC skipped (only 35 valid rows)
# ❌ APYX skipped (only 35 valid rows)
# ❌ AQLT skipped (only 35 valid rows)
# ❌ AQMS skipped (only 35 valid rows)
# ❌ AQN skipped (only 35 valid rows)
# ❌ AQNB skipped (only 35 valid rows)
# ❌ ATLC skipped (only 0 valid rows)
# ❌ ATLCL skipped (only 0 valid rows)
# ❌ ATLCP skipped (only 0 valid rows)
# ❌ ATLCZ skipped (only 0 valid rows)
# ❌ ATLN skipped (only 0 valid rows)
# ❌ ATLO skipped (only 0 valid rows)
# ❌ ATLX skipped (only 0 valid rows)
# ❌ ATMC skipped (only 0 valid rows)
# ❌ BATRA skipped (only 0 valid rows)
# ❌ BATT skipped (only 0 valid rows)
# ❌ BAUG skipped (only 0 valid rows)
# ❌ BAYA skipped (only 0 valid rows)
# ❌ BAYAR skipped (only 0 valid rows)
# ❌ BCV skipped (only 13 valid rows)
# ❌ BCV$A skipped (only 13 valid rows)
# ❌ BCX skipped (only 13 valid rows)
# ❌ BCYC skipped (only 13 valid rows)
# ❌ BDC skipped (only 13 valid rows)
# ❌ BDCX skipped (only 13 valid rows)
# ❌ BDCZ skipped (only 13 valid rows)
# ❌ BDEC skipped (only 13 valid rows)
# ❌ BDVG skipped (only 0 valid rows)
# ❌ BDX skipped (only 0 valid rows)
# ❌ BE skipped (only 0 valid rows)
# ❌ BEAGR skipped (only 0 valid rows)
# ❌ BTOP skipped (only 20 valid rows)
# ❌ BTR skipped (only 20 valid rows)
# ❌ BTRN skipped (only 20 valid rows)
# ❌ BTSG skipped (only 20 valid rows)
# ❌ BTSGU skipped (only 20 valid rows)
# ❌ BTT skipped (only 20 valid rows)
# ❌ BTU skipped (only 20 valid rows)
# ❌ BTX skipped (only 20 valid rows)
# ❌ BWFG skipped (only 2 valid rows)
# ❌ BWG skipped (only 2 valid rows)
# ❌ BWIN skipped (only 2 valid rows)
# ❌ BWLP skipped (only 2 valid rows)
# ❌ BWMN skipped (only 2 valid rows)
# ❌ BWMX skipped (only 2 valid rows)
# ❌ BWNB skipped (only 2 valid rows)
# ❌ BWSN skipped (only 2 valid rows)
# ❌ BYRE skipped (only 0 valid rows)
# ❌ BYSI skipped (only 0 valid rows)
# ❌ BZAIW skipped (only 0 valid rows)
# ❌ BZFD skipped (only 0 valid rows)
# ❌ BZFDW skipped (only 0 valid rows)
# ❌ CEF skipped (only 36 valid rows)
# ❌ CEFA skipped (only 36 valid rows)
# ❌ CEFD skipped (only 36 valid rows)
# ❌ CEFS skipped (only 36 valid rows)
# ❌ CEG skipped (only 36 valid rows)
# ❌ CELC skipped (only 36 valid rows)
# ❌ CELG.R skipped (only 36 valid rows)
# ❌ CELH skipped (only 36 valid rows)
# ❌ CIK skipped (only 23 valid rows)
# ❌ CIL skipped (only 23 valid rows)
# ❌ CIM skipped (only 23 valid rows)
# ❌ CLWT skipped (only 31 valid rows)
# ❌ CLX skipped (only 31 valid rows)
# ❌ CLYM skipped (only 31 valid rows)
# ❌ CM skipped (only 31 valid rows)
# ❌ CMA skipped (only 31 valid rows)
# ❌ CMBM skipped (only 31 valid rows)
# ❌ CMBS skipped (only 31 valid rows)
# ❌ CMBT skipped (only 31 valid rows)
# ❌ CRCT skipped (only 12 valid rows)
# ❌ CRD.A skipped (only 12 valid rows)
# ❌ CRD.B skipped (only 12 valid rows)
# ❌ CRDF skipped (only 12 valid rows)
# ❌ CRDL skipped (only 12 valid rows)
# ❌ CRDO skipped (only 12 valid rows)
# ❌ CRDT skipped (only 12 valid rows)
# ❌ DOLE skipped (only 0 valid rows)
# ❌ EGY skipped (only 12 valid rows)
# ❌ EHAB skipped (only 12 valid rows)
# ❌ EMHY skipped (only 34 valid rows)
# ❌ EMIF skipped (only 34 valid rows)
# ❌ EML skipped (only 34 valid rows)
# ❌ FESM skipped (only 18 valid rows)
# ❌ FET skipped (only 18 valid rows)
# ❌ FETH skipped (only 18 valid rows)
# ❌ FEUS skipped (only 18 valid rows)
# ❌ FEUZ skipped (only 18 valid rows)
# ❌ FEX skipped (only 18 valid rows)
# ❌ FEZ skipped (only 18 valid rows)
# ❌ FF skipped (only 18 valid rows)
# ❌ FFLG skipped (only 0 valid rows)
# ❌ FFLS skipped (only 0 valid rows)
# ❌ FFLV skipped (only 0 valid rows)
# ❌ FFND skipped (only 0 valid rows)
# ❌ FFOG skipped (only 0 valid rows)
# ❌ GOAU skipped (only 25 valid rows)
# ❌ GOCO skipped (only 25 valid rows)
# ❌ GOCT skipped (only 25 valid rows)
# ❌ GOEX skipped (only 25 valid rows)
# ❌ GOF skipped (only 25 valid rows)
# ❌ GOGO skipped (only 25 valid rows)
# ❌ HODL skipped (only 0 valid rows)
# ❌ HOLO skipped (only 0 valid rows)
# ❌ HOLOW skipped (only 0 valid rows)
# ❌ HURN skipped (only 1 valid rows)
# ❌ HUYA skipped (only 1 valid rows)
# ❌ HVAC skipped (only 1 valid rows)
# ❌ HVII skipped (only 1 valid rows)
# ❌ HVIIR skipped (only 1 valid rows)
# ❌ HVIIU skipped (only 1 valid rows)
# ❌ HVT skipped (only 1 valid rows)
# ❌ HVT.A skipped (only 1 valid rows)
# ❌ ICSH skipped (only 29 valid rows)
# ❌ IFRA skipped (only 29 valid rows)
# ❌ IFRX skipped (only 29 valid rows)
# ❌ IFS skipped (only 29 valid rows)
# ❌ IFV skipped (only 29 valid rows)
# ❌ IG skipped (only 29 valid rows)
# ❌ IGA skipped (only 29 valid rows)
# ❌ IGBH skipped (only 29 valid rows)
# ❌ IGC skipped (only 29 valid rows)
# ❌ IJUN skipped (only 29 valid rows)
# ❌ IKNA skipped (only 29 valid rows)
# ❌ IKT skipped (only 29 valid rows)
# ❌ ILAG skipped (only 29 valid rows)
# ❌ ILCB skipped (only 29 valid rows)
# ❌ ILCG skipped (only 29 valid rows)
# ❌ ILCV skipped (only 29 valid rows)
# ❌ ILDR skipped (only 29 valid rows)
# ❌ IMNN skipped (only 0 valid rows)
# ❌ IMPPP skipped (only 0 valid rows)
# ❌ IMRX skipped (only 0 valid rows)
# ❌ IMST skipped (only 4 valid rows)
# ❌ IMTB skipped (only 4 valid rows)
# ❌ IMTE skipped (only 4 valid rows)
# ❌ IREN skipped (only 11 valid rows)
# ❌ IRET skipped (only 11 valid rows)
# ❌ IRM skipped (only 11 valid rows)
# ❌ IROC skipped (only 11 valid rows)
# ❌ IROHU skipped (only 11 valid rows)
# ❌ IROHW skipped (only 11 valid rows)
# ❌ IRON skipped (only 11 valid rows)
# ❌ IROQ skipped (only 11 valid rows)
# ❌ IWDL skipped (only 11 valid rows)
# ❌ IWF skipped (only 11 valid rows)
# ❌ IWFG skipped (only 11 valid rows)
# ❌ IWFL skipped (only 11 valid rows)
# ❌ IWL skipped (only 11 valid rows)
# ❌ IWLG skipped (only 11 valid rows)
# ❌ IWM skipped (only 11 valid rows)
# ❌ IWMI skipped (only 11 valid rows)
# ❌ JULZ skipped (only 21 valid rows)
# ❌ JUNE skipped (only 21 valid rows)
# ❌ JUNM skipped (only 21 valid rows)
# ❌ JUNP skipped (only 21 valid rows)
# ❌ JUNS skipped (only 21 valid rows)
# ❌ JUNT skipped (only 21 valid rows)
# ❌ JUNW skipped (only 21 valid rows)
# ❌ JUNZ skipped (only 16 valid rows)
# ❌ JUSA skipped (only 16 valid rows)
# ❌ JUST skipped (only 16 valid rows)
# ❌ JVA skipped (only 16 valid rows)
# ❌ JVAL skipped (only 16 valid rows)
# ❌ JVSA skipped (only 16 valid rows)
# ❌ JVSAR skipped (only 16 valid rows)
# ❌ JVSAU skipped (only 16 valid rows)
# ❌ KVLE skipped (only 0 valid rows)
# ❌ KVUE skipped (only 0 valid rows)
# ❌ KW skipped (only 0 valid rows)
# ❌ KWE skipped (only 0 valid rows)
# ❌ KWM skipped (only 0 valid rows)
# ❌ MUST skipped (only 32 valid rows)
# ❌ MUU skipped (only 32 valid rows)
# ❌ MUX skipped (only 32 valid rows)
# ❌ MVAL skipped (only 32 valid rows)
# ❌ MVBF skipped (only 32 valid rows)
# ❌ MVF skipped (only 32 valid rows)
# ❌ MVFD skipped (only 32 valid rows)
# ❌ MVFG skipped (only 32 valid rows)
# ❌ NEXT skipped (only 30 valid rows)
# ❌ NFBK skipped (only 30 valid rows)
# ❌ NFE skipped (only 30 valid rows)
# ❌ NFEB skipped (only 30 valid rows)
# ❌ NFG skipped (only 30 valid rows)
# ❌ NFGC skipped (only 30 valid rows)
# ❌ NFJ skipped (only 30 valid rows)
# ❌ NRXP skipped (only 35 valid rows)
# ❌ NUSB skipped (only 8 valid rows)
# ❌ NUSC skipped (only 8 valid rows)
# ❌ NUTX skipped (only 8 valid rows)
# ❌ NUV skipped (only 8 valid rows)
# ❌ NUVB skipped (only 8 valid rows)
# ❌ NUVB.W skipped (only 8 valid rows)
# ❌ NUVL skipped (only 8 valid rows)
# ❌ PTBD skipped (only 3 valid rows)
# ❌ PTC skipped (only 3 valid rows)
# ❌ PTCT skipped (only 3 valid rows)
# ❌ PTEC skipped (only 3 valid rows)
# ❌ PTEN skipped (only 3 valid rows)
# ❌ PTEU skipped (only 3 valid rows)
# ❌ PTF skipped (only 3 valid rows)
# ❌ PTGX skipped (only 3 valid rows)
# ❌ QTPI skipped (only 31 valid rows)
# ❌ QTR skipped (only 31 valid rows)
# ❌ QTUM skipped (only 31 valid rows)
# ❌ QTWO skipped (only 31 valid rows)
# ❌ QUAD skipped (only 31 valid rows)
# ❌ QUAL skipped (only 31 valid rows)
# ❌ QUBT skipped (only 31 valid rows)
# ❌ QUIK skipped (only 31 valid rows)
# ❌ RAC.W skipped (only 0 valid rows)
# ❌ RACE skipped (only 0 valid rows)
# ❌ RAFE skipped (only 0 valid rows)
# ❌ RAIL skipped (only 0 valid rows)
# ❌ RAMP skipped (only 0 valid rows)
# ❌ SAT skipped (only 0 valid rows)
# ❌ SATL skipped (only 0 valid rows)
# ❌ SATS skipped (only 0 valid rows)
# ❌ SATX skipped (only 0 valid rows)
# ❌ SAUG skipped (only 0 valid rows)
# ❌ SKT skipped (only 0 valid rows)
# ❌ SLNHP skipped (only 31 valid rows)
# ❌ SLNO skipped (only 31 valid rows)
# ❌ SLNZ skipped (only 31 valid rows)
# ❌ SLP skipped (only 31 valid rows)
# ❌ SLQD skipped (only 31 valid rows)
# ❌ SLQT skipped (only 31 valid rows)
# ❌ SLRC skipped (only 31 valid rows)
# ❌ SLRN skipped (only 31 valid rows)
# ❌ THQ skipped (only 21 valid rows)
# ❌ THR skipped (only 21 valid rows)
# ❌ THRD skipped (only 21 valid rows)
# ❌ THRM skipped (only 21 valid rows)
# ❌ THRO skipped (only 21 valid rows)
# ❌ TYL skipped (only 6 valid rows)
# ❌ TYLD skipped (only 6 valid rows)
# ❌ TYLG skipped (only 6 valid rows)
# ❌ TYO skipped (only 6 valid rows)
# ❌ TYRA skipped (only 6 valid rows)
# ❌ TZA skipped (only 6 valid rows)
# ❌ TZOO skipped (only 6 valid rows)
# ❌ TZUP skipped (only 6 valid rows)
# ❌ U skipped (only 21 valid rows)
# ❌ UAA skipped (only 21 valid rows)
# ❌ UAE skipped (only 21 valid rows)
# ❌ UAL skipped (only 21 valid rows)
# ❌ UAMY skipped (only 21 valid rows)
# ❌ UAN skipped (only 21 valid rows)
# ❌ UAPR skipped (only 21 valid rows)
# ❌ UAUG skipped (only 21 valid rows)
# ❌ UEIC skipped (only 21 valid rows)
# ❌ UEVM skipped (only 6 valid rows)
# ❌ UFCS skipped (only 21 valid rows)
# ❌ UFEB skipped (only 21 valid rows)
# ❌ UFG skipped (only 21 valid rows)
# ❌ UFI skipped (only 21 valid rows)
# ❌ UFIV skipped (only 21 valid rows)
# ❌ UFO skipped (only 21 valid rows)
# ❌ UFPI skipped (only 21 valid rows)
# ❌ VBIL skipped (only 26 valid rows)
# ❌ VBK skipped (only 26 valid rows)
# ❌ VBND skipped (only 26 valid rows)
# ❌ VBNK skipped (only 26 valid rows)
# ❌ VBR skipped (only 26 valid rows)
# ❌ VBTX skipped (only 26 valid rows)
# ❌ VC skipped (only 26 valid rows)
# ❌ VCEB skipped (only 26 valid rows)
# ❌ VTYX skipped (only 1 valid rows)
# ❌ VUG skipped (only 1 valid rows)
# ❌ VUSB skipped (only 1 valid rows)
# ❌ VUSE skipped (only 1 valid rows)
# ❌ VUZI skipped (only 1 valid rows)
# ❌ VV skipped (only 1 valid rows)
# ❌ VVOS skipped (only 1 valid rows)
# ❌ VVPR skipped (only 1 valid rows)
# ❌ WISE skipped (only 26 valid rows)
# ❌ WIT skipped (only 26 valid rows)
# ❌ WIW skipped (only 26 valid rows)
# ❌ WIX skipped (only 26 valid rows)
# ❌ WK skipped (only 26 valid rows)
# ❌ WKC skipped (only 26 valid rows)
# ❌ WKEY skipped (only 26 valid rows)
# ❌ WKHS skipped (only 26 valid rows)
# ❌ XVOL skipped (only 11 valid rows)
# ❌ XVV skipped (only 11 valid rows)
# ❌ XWEL skipped (only 11 valid rows)
# ❌ XXCH skipped (only 11 valid rows)
# ❌ XXII skipped (only 11 valid rows)
# ❌ XXRP skipped (only 11 valid rows)
# ❌ XYF skipped (only 11 valid rows)
# ❌ XYL skipped (only 11 valid rows)
# ✅ 10995 valid tickers saved to: /content/drive/MyDrive/StockProject/StockProjectDataPrep/valid_tickers.csv
